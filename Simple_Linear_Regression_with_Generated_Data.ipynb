# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhtampubolon/SDPM2025/blob/main/Simple_Linear_Regression_with_Generated_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

np.random.seed(42)
X = np.random.rand(100, 1) * 10
y = 2 * X + 1 + np.random.randn(100, 1) * 2

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Coefficient:", model.coef_[0][0])
print("Intercept:", model.intercept_[0])
# Out:
# Coefficient: 1.9080453545753935
# Intercept: 1.4301923150934996

# %%
# Plot 1: Scatter and fitted line
plt.figure(figsize=(8, 4))
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.title('Data and Fitted Line')
plt.show()

# %%
# Plot 2: Residuals
residuals = y - model.predict(X)
plt.figure(figsize=(8, 4))
plt.scatter(X, residuals, color='green')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.show()
