# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhtampubolon/SDPM2025/blob/main/Simple_Linear_Regression_with_Synthetic_Data_Using_ScikitLearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Synthetic data with random seed
np.random.seed(42)
X = np.random.rand(100, 1) * 10
y = 2 * X + np.random.randn(100, 1) * 2

# %%
# Train model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predictions and metrics
y_pred = model.predict(X)
print("Coefficient:", model.coef_[0][0])
print("R2 Score:", r2_score(y, y_pred))
# Out:
# Coefficient: 1.9080453545753935
# R2 Score: 0.9081437156468248

# %%
# Visual 1: Scatter plot with regression line
plt.figure(figsize=(8, 4))
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.legend()
plt.title('Data and Regression Line')
plt.show()

# %%
# Visual 2: Residual plot
residuals = y - y_pred
plt.figure(figsize=(8, 4))
plt.scatter(X, residuals, color='green')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.show()
