# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhtampubolon/SDPM2025/blob/main/Linear_Regression_with_Longley_Dataset_Statsmodels_Builtin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
data = sm.datasets.longley.load_pandas()
y = data.endog  # TOTEMP
X = data.exog
X = sm.add_constant(X)

model = sm.OLS(y, X)
results = model.fit()

# %%
print("Coefficients:\n", results.params)
print("R-squared:", results.rsquared)
# Out:
# Coefficients:
#  const     -3.482259e+06
# GNPDEFL    1.506187e+01
# GNP       -3.581918e-02
# UNEMP     -2.020230e+00
# ARMED     -1.033227e+00
# POP       -5.110411e-02
# YEAR       1.829151e+03
# dtype: float64
# R-squared: 0.9954790045772896

# %%
# Plot 1: Actual vs Fitted
fitted = results.fittedvalues
plt.figure(figsize=(8, 4))
plt.scatter(y, fitted, color='blue')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--')
plt.title('Actual vs Fitted')
plt.show()

# %%
# Plot 2: Residuals vs Fitted
residuals = results.resid
plt.figure(figsize=(8, 4))
plt.scatter(fitted, residuals, color='green')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuals vs Fitted')
plt.show()
